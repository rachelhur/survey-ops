# %%
import numpy as np
import matplotlib.pyplot as plt

import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# 2025-10-29 19:05:47.110874: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-10-29 19:05:47.110893: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# # not necessary - just for fun if wanna see visuals of gym's already implemented Box2d environments
# !pip install swig
# !pip install gymnasium[classic-control]

# %% [markdown]
# All of the pre-implemented environments are printed below

# %%
gym.pprint_registry()
# Out:
# ===== classic_control =====
# Acrobot-v1             CartPole-v0            CartPole-v1
# MountainCar-v0         MountainCarContinuous-v0 Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0     phys2d/CartPole-v1     phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3       BipedalWalkerHardcore-v3 CarRacing-v3
# LunarLander-v3         LunarLanderContinuous-v3
# ===== toy_text =====
# Blackjack-v1           CliffWalking-v0        FrozenLake-v1
# FrozenLake8x8-v1       Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0   tabular/CliffWalking-v0
# ===== mujoco =====
# Ant-v2                 Ant-v3                 Ant-v4
# Ant-v5                 HalfCheetah-v2         HalfCheetah-v3
# HalfCheetah-v4         HalfCheetah-v5         Hopper-v2
# Hopper-v3              Hopper-v4              Hopper-v5
# Humanoid-v2            Humanoid-v3            Humanoid-v4
# Humanoid-v5            HumanoidStandup-v2     HumanoidStandup-v4
# ...

# %%
# Create a simple environment perfect for beginners
env = gym.make('CartPole-v1', render_mode='human')
# Always reset an environment after `make()` and whenever starting a new episode. outputs first observation and starting info
observation, info = env.reset()

# %%
env.action_space, env.observation_space
# Out:
# (Discrete(2),
#  Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32))

# %%
# if pole angle is neg (pos) and cart pos is pos (neg), step back

# %%
# Reset environment to start a new episode. outputs first observation and starting info
observation, info = env.reset()

# %%
episode_over = False
total_reward = 0

# %%
while not episode_over:
    # Choose an action: 0 = push cart left, 1 = push cart right
    # here is simple, random sampling
    action = env.action_space.sample()  # Random action for now - real agents will be smarter!

    # env.step() takes the action and  
    observation, reward, terminated, truncated, info = env.step(action)

    # reward: +1 for each step the pole stays upright
    # terminated: True if pole falls too far (agent failed)
    # truncated: True if we hit the time limit (500 steps)

    total_reward += reward
    episode_over = terminated or truncated

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Episode finished! Total reward: 30.0

# %% [markdown]
# # SB3 + gymnasium

# %%
# Instantiate the agent
model = DQN("MlpPolicy", env, verbose=1)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(2e5), progress_bar=True)
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading
# Out:
# Output()
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1117     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1153     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 164      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.565    |
# ...

# %%
model = DQN.load('dqn_lunar', env=env)
# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 6
#       1 model = DQN.load('dqn_lunar', env=env)
#       2 # Evaluate the agent
#       3 # NOTE: If you use wrappers with your environment that modify rewards,
#       4 #       this will be reflected here. To evaluate with original rewards,
#       5 #       wrap environment in a "Monitor" wrapper before other wrappers.
# ----> 6 mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
#
# File ~/miniconda3/envs/cosmo_ml/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:97, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      90 while (episode_counts < episode_count_targets).any():
# ...

# %%
mean_reward, std_reward
# Out:
# (178.8, 9.325234581499814)

# %%
# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 6
#       4 for i in range(1000):
#       5     action, _states = model.predict(obs, deterministic=True)
# ----> 6     obs, rewards, dones, info = vec_env.step(action)
#       7     vec_env.render("human")
#
# File ~/miniconda3/envs/cosmo_ml/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/miniconda3/envs/cosmo_ml/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
# ...

# %%
60*60*8
# Out:
# 28800

# %%
dsfadsf555

# %%
[study.best_params for study in [study_A2C, study_DQN, study_PPO]]
# Out:
# [{'learning_rate': 0.0029125082432144966,
#   'gamma': 0.9685965294186208,
#   'entropy_coef': 0.016898713047774697},
#  {'learning_rate': 0.007477227186831524,
#   'gamma': 0.9517612826826944,
#   'buffer_size': 350000},
#  {'learning_rate': 0.0008331673463916613,
#   'gamma': 0.9512598128554376,
#   'clip_range': 0.2741024533150132,
#   'n_epochs': 20}]

# %%
[study.best_params for study in [study_A2C, study_DQN, study_PPO]]
# Out:
# [{'learning_rate': 0.0029125082432144966,
#   'gamma': 0.9685965294186208,
#   'entropy_coef': 0.016898713047774697},
#  {'learning_rate': 0.007477227186831524,
#   'gamma': 0.9517612826826944,
#   'buffer_size': 350000},
#  {'learning_rate': 0.0008331673463916613,
#   'gamma': 0.9512598128554376,
#   'clip_range': 0.2741024533150132,
#   'n_epochs': 20}]

# %%
[study.best_params for study in [study_A2C, study_DQN, study_PPO]]
# Out:
# [{'learning_rate': 0.0029125082432144966,
#   'gamma': 0.9685965294186208,
#   'entropy_coef': 0.016898713047774697},
#  {'learning_rate': 0.007477227186831524,
#   'gamma': 0.9517612826826944,
#   'buffer_size': 350000},
#  {'learning_rate': 0.0008331673463916613,
#   'gamma': 0.9512598128554376,
#   'clip_range': 0.2741024533150132,
#   'n_epochs': 20}]
