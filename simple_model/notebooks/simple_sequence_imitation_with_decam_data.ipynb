# %%
import numpy as np
import matplotlib.pyplot as plt
import random

import gymnasium as gym

from stable_baselines3 import DQN, PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

from astropy.io import fits
import math
import pandas as pd
import time
from datetime import datetime

from gymnasium.spaces import Dict, Box, Discrete

from typing import Optional
import numpy as np
# Out:
# 2025-11-05 21:03:49.228593: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-05 21:03:49.233852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762398229.240053   68520 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762398229.242210   68520 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762398229.247468   68520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762398229.247478   68520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762398229.247480   68520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762398229.247480   68520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-05 21:03:49.249630: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load data

# %%
hdulist = fits.open('../data/decam-exposures-20250829.fits')

# %%
hdulist[1].data.names
# Out:
# ['expnum',
#  'ra',
#  'dec',
#  'exptime',
#  'filter',
#  'propid',
#  'program',
#  'teff',
#  'fwhm',
#  'datetime']

# %% [markdown]
# ### Preprocess data (remove nans and convenient formats)

# %%
# load data
data = {key: hdulist[1].data[key] for key in hdulist[1].data.names}

# remove teff=nan
mask1 = np.isnan(data['fwhm'])
mask2 = np.isnan(data['teff'])
subs_data = {key: data[key][~mask1 & ~mask2] for key in data.keys()}

# change _VLF to array
for key in ['filter', 'propid', 'program', 'datetime']:
    subs_data[key] = subs_data[key].base

# join ind. chars for program names and datetimes
subs_data['program'] = np.array(["".join(prog) for prog in subs_data['program']])
subs_data['datetime'] = np.array(["".join(subs_data['datetime'][i]) for i in range(len(subs_data['datetime']))])

# remove datetime='None'
mask = np.array([False if 'None' in dt else True for dt in subs_data['datetime']])
subs_data = {key: subs_data[key][mask] for key in subs_data.keys()}

# %%
filters = ['g', 'r', 'u', 'z', 'i', 'Y']
filter_to_color = {filt: i for i, filt in enumerate(filters)}
filter_to_color
# Out:
# {'g': 0, 'r': 1, 'u': 2, 'z': 3, 'i': 4, 'Y': 5}

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].hist(subs_data['teff'], bins=1000);
axs[0].set_xlim(-1, 2.5)
axs[0].set_xlabel(r'$\tau$', fontsize=20)

axs[1].hist(subs_data['fwhm'], bins=1000);
axs[1].set_xlim(-1, 6)
axs[1].set_xlabel('fwhm', fontsize=20)

colors = [filter_to_color[key[0]] for key in subs_data['filter']]
C = axs[2].scatter(subs_data['ra'], subs_data['dec'], s=1, c=colors, alpha=.5)
cbar = plt.colorbar(C)
cbar.ax.set_yticklabels(filters)
axs[2].set_xlabel('ra', fontsize=20)
axs[2].set_ylabel('dec', fontsize=20)

fig.suptitle('All DES data')
fig.tight_layout()
# Out:
# /tmp/ipykernel_68520/1584627705.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(filters)

# %%
# get unique dates and frequency
unique_dates, counts = np.unique([dt[:10] for dt in subs_data['datetime']], return_counts=True)
n_obs_by_date = {'dates': unique_dates, 'n_obs': counts}

# %%
for i in range(-1, -10, -1):
    print(i, n_obs_by_date['dates'][i], n_obs_by_date['n_obs'][i])
# Out:
# -1 2025-08-29 147
# -2 2025-08-28 15
# -3 2025-08-07 10
# -4 2025-08-05 379
# -5 2025-08-04 298
# -6 2025-08-03 14
# -7 2025-07-30 174
# -8 2025-07-29 64
# -9 2025-07-28 27

# %%
el, counts = np.unique((subs_data['ra'], subs_data['dec']), return_counts=True)

# %%
# choose year, month, date
YEAR, MONTH, DAY = 2025, 8, 5
DATETIME = f'{YEAR}-{MONTH}-{DAY}'

# %%
# reformat datetime
FORMAT = "%Y-%m-%d%H:%M:%S"
if type(subs_data['datetime'][0]) != type(datetime):
    subs_data['datetime'] = np.array([datetime.strptime(dt, FORMAT) for dt in subs_data['datetime']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2 FORMAT = "%Y-%m-%d%H:%M:%S"
#       3 if type(subs_data['datetime'][0]) != type(datetime):
# ----> 4     subs_data['datetime'] = np.array([datetime.strptime(dt, FORMAT) for dt in subs_data['datetime']])
#
# Cell In[25], line 4, in <listcomp>(.0)
#       2 FORMAT = "%Y-%m-%d%H:%M:%S"
#       3 if type(subs_data['datetime'][0]) != type(datetime):
# ----> 4     subs_data['datetime'] = np.array([datetime.strptime(dt, FORMAT) for dt in subs_data['datetime']])
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
# pick out observations in year, month, date 
mask = np.array([True if (dt.year == YEAR) and (dt.month == MONTH) and (dt.day == DAY) else False for dt in subs_data['datetime']])
date_data = {key: subs_data[key][mask] for key in subs_data.keys()}
date_filters = np.unique(date_data['filter'])

# %%
el, counts = np.unique((date_data['ra'], date_data['dec']), return_counts=True)

# %%
mask_g = date_data['filter'] == ['g']
mask_i = date_data['filter'] == ['i']
mask_r = date_data['filter'] == ['r']
mask_z = date_data['filter'] == ['z']

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].hist(date_data['teff'], bins=15);
# axs[0].set_xlim(-1, 2.5)
axs[0].set_xlabel(r'$\tau$', fontsize=20)

axs[1].hist(date_data['fwhm'], bins=20);
# axs[1].set_xlim(-1, 6)
axs[1].set_xlabel('fwhm', fontsize=20)

markers = ['^', '*', 'o', 's']
for i, (filt, mask) in enumerate(zip(date_filters, [mask_g, mask_i, mask_r, mask_z])):
    axs[2].scatter(date_data['ra'][mask], date_data['dec'][mask], s=100, label=filt[0], marker=markers[i], edgecolor='black', alpha=.8)
# cbar = plt.colorbar(C)
# cbar.ax.set_yticklabels(date_filters)
axs[2].set_xlabel('ra', fontsize=20)
axs[2].set_ylabel('dec', fontsize=20)
axs[2].legend()

fig.suptitle('Observations for ' + DATETIME)
fig.tight_layout()

# %%
plt.scatter(date_data['exptime'], date_data['exptime'] * date_data['teff'])

# %%
fig, axs = plt.subplots(1, 2,figsize=(10, 5))
axs[0].set_xlabel('exposure time', fontsize=20)
axs[0].set_ylabel(r'$\tau * t_{exp}$', fontsize=20)
axs[0].scatter(date_data['exptime'], date_data['exptime'] * date_data['teff'])

axs[1].hist(date_data['exptime'] * date_data['teff'], label=r'$\tau * t_{exp}$')
axs[1].set_xlabel(r'$\tau * t_{exp}$', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ### Include astropy coords

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord

# %%
date_data['coords'] = SkyCoord(ra=date_data['ra']*u.degree, dec=date_data['dec']*u.degree)

# %%
plt.plot( [dt.seconds for dt in np.diff(date_data['datetime'])] )
plt.ylim(0, 1000)
plt.xlabel('Time between start of each observation (s)')
# Out:
# Text(0.5, 0, 'Time between start of each observation (s)')

# %%
plt.plot(date_data['ra'], label='ra')
plt.plot(date_data['dec'], label='dec')

# %%
ra_dec = np.array([str(ra) + '-' + str(dec) for ra, dec in zip(date_data['ra'], date_data['dec'])])

uniq_ra_dec, counts = np.unique(ra_dec, return_counts = True)

map_coord_to_field = {coord: field_id for field_id, coord in enumerate(uniq_ra_dec)}

target_sequence = [map_coord_to_field[coord] for coord in ra_dec]
Nf = len(uniq_ra_dec)
nv_max = np.max(counts)

# %%
plt.plot(target_sequence)
plt.xlabel('chronological ordering of observations')
plt.ylabel('field index')
# Out:
# Text(0, 0.5, 'field index')

# %% [markdown]
# ## Set up environment

# %%
class MoonSkyModel:
    def __init__(self, ra, dec, filter)):
        self.ra = ra
        self.dec

# %%
from gymnasium.spaces import Dict, Box, Discrete

from typing import Optional
import numpy as np


class DECAMEnv(gym.Env):
    def __init__(
        self, 
        Nf, 
        target_sequence, 
        nv_max, 
        off_by_lim, 
        MoonSkyModel=None,
        
        ):
        self.Nf = Nf # number of fields
        # self.T = 1 # 28800sec = 8hrs
        self.nv_max = nv_max
        self.target_sequence = target_sequence
        self.off_by_lim = off_by_lim
        # "Teff_meas": Box(0, 1, shape=(Nf,), dtype=np.float32),

        #TODO
        # Initialize positions - will be set in reset()
        self._field_id = -1
        # self._t = -1
        self._nvisits = np.full(shape=(Nf,), fill_value=-1, dtype=np.int32)
        # self._Teff_pred = np.full(shape=(Nf,), fill_value=-1, dtype=np.float32)
        self._index = -1
        self._sequence = []

        # self._possible_actions = [i for i in range(Nf)]

        #TODO
        # Define what the agent can observe
        # Dict space gives us structured, human-readable observations
        self.observation_space = gym.spaces.Dict(
            {
                # "t": Box(0, T, shape=None, dtype=np.float32),
                "field_id": Discrete(n=Nf, start=0),
                "nvisits": Box(0, nv_max, shape=(Nf,), dtype=np.int32),
                "index": Discrete(n=len(self.target_sequence), start=0)
                # "Teff_pred": Box(0, 1, shape=(Nf,), dtype=np.float32),
                    #filter
            }
        )
        
        # # Map action numbers to field
        self._action_to_field_id = {i:i for i in range(Nf)}

        self.action_space = gym.spaces.Discrete(self.Nf)

        # remove fields that have 
        
    def _get_obs(self):
        """Convert internal state to observation format.
    
        Returns:
            dict: Observation with agent and target positions
        """
        return {
            # "t": self._t,
            "field_id": self._field_id,
            "nvisits": self._nvisits,
            "index": self._index
            # "Teff_pred": self._Teff_pred,
        }

    def _get_info(self, chosen_field_id=None, correct=None):
        """Compute auxiliary information for debugging.

        Returns:
            
        """
        return {'chosen_field_id': chosen_field_id, 'correct': correct}

    def reset(self, seed: Optional[int] = None, options: Optional[dict] = None):
        """Start a new episode.

        Args:
            seed: Random seed for reproducible episodes
            options: Additional configuration (unused in this example)

        Returns:
            tuple: (observation, info) for the initial state
        """
        # IMPORTANT: Must call this first to seed the random number generator
        super().reset(seed=seed)

        # initialize number of visits
        self._nvisits = np.full(shape=(self.Nf,), fill_value=0, dtype=np.int32)
        
        # Randomly choose initial field id and add 1 visit to nvisits list
        # self._field_id = int(self.np_random.integers(0, self.Nf, size=1, dtype=int)[0])
        self._field_id = self.target_sequence[0]
        # self._field_id = self.np_random.integers(0, self.Nf, size=1, dtype=int).tolist()[0]
        self._nvisits[self._field_id] += 1
        self._index = 0
        # self._t = np.array([0.0], dtype=np.float32)
        # self._Teff_pred = np.linspace(0.1, .98, num=self.Nf, dtype=np.float32)
        
        observation = self._get_obs()
        info = self._get_info()

        return observation, info

    def step(self, action):
        """Execute one timestep within the environment.

        Args:

        Returns:
        """
        # # choose random field for next observation
        # list_idx = self.np_random.integers(low=0, high=len(self._possible_actions), dtype=int)
        # proposed_field = self._possible_actions[list_idx]
        # self._nvisits[proposed_field] += 1
        # self._field_id = proposed_field
        self._index += 1            
        # get current field_id from action
        self._field_id = self._action_to_field_id[action]
        # add to nvisits
        self._nvisits[self._field_id] += 1

        # Simple reward structure: +1 for reaching target, 0 otherwise
        target_field = self.target_sequence[self._index]
        correct = self._field_id == target_field
        off_by_val = np.abs(self._field_id - target_field) <= self.off_by_lim
        if correct:
            reward = 1
        elif off_by_val:
            reward = .2
        else:
            reward = 0
            
        survey_complete = (self._index == len(self.target_sequence)-1)
        
        # end condition
        terminated = survey_complete
        truncated = False

        # get obs and info
        observation = self._get_obs()
        info = self._get_info(self._field_id, correct)

        return observation, reward, terminated, truncated, info

# %%
# Register the environment so we can create it with gym.make()
gym.register(
    id="gymnasium_env/SimpleTel-v1",
    entry_point=SimpleTelescopeEnvV1,
    max_episode_steps=len(target_sequence),  # Prevent infinite episodes
)
# Out:
# /home/rachel/miniconda3/envs/cosmo_ml/lib/python3.10/site-packages/gymnasium/envs/registration.py:642: UserWarning: WARN: Overriding environment gymnasium_env/SimpleTel-v1 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
env = gym.make("gymnasium_env/SimpleTel-v1", Nf=Nf, target_sequence=target_sequence, nv_max=nv_max, off_by_lim=20)
# Create multiple environments for parallel training
# vec_env = gym.make_vec("gymnasium_env/GridWorld-v0", num_envs=3)

# %%
from gymnasium.utils.env_checker import check_env

# This will catch many common issues
try:
    check_env(env.unwrapped)
    print("Environment passes all checks!")
except Exception as e:
    print(f"Environment has issues: {e}")
# Out:
# Environment passes all checks!

# %%
# quick check to make sure environment is doing what's intended

# observation_list = []
# reward_list = []
# terminated_list = []
# truncated_list = []
# info_list = []

# observation, info = env.reset()
# observation_list.append(observation)
# reward_list.append(reward)

# for i in range(20):
#     try:
#         observation, reward, terminated, truncated, info = env.step(true_actions[i+1])
#         observation_list.append(observation)
#         reward_list.append(reward)
#         terminated_list.append(terminated)
#         truncated_list.append(truncated)
#         info_list.append(info)
#     except:
#         continue
# [observation_list[i]['field_id'] for i in range(len(observation_list))]

# %% [markdown]
# # Learn with RL model

# %%
lr = 1e-3

# %%
model = PPO(
    "MultiInputPolicy",
    env,
    verbose=1,
    learning_rate=lr,
    # target_update_interval=int(len(target_sequence)*1),
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ## How does model do with no training?

# %%
seed = 16

# %%
observation_list = []
reward_list = []
terminated_list = []
truncated_list = []
info_list = []

obs, info = env.reset(seed=seed)
observation_list.append(obs)
info_list.append(info)
for i in range(len(target_sequence)):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action.tolist())
    observation_list.append(obs)
    reward_list.append(reward)
    terminated_list.append(terminated)
    truncated_list.append(truncated)
    info_list.append(info)
    if terminated or truncated:
        print(i)
        break
# Out:
# 377

# %%
proposed_survey = [observation_list[i]['field_id'] for i in range(len(observation_list))]
print(proposed_survey)
# Out:
# [29, 66, 46, 142, 142, 170, 170, 170, 8, 8, 8, 8, 101, 283, 101, 283, 101, 283, 170, 283, 170, 283, 170, 283, 170, 8, 198, 8, 198, 8, 8, 198, 8, 283, 171, 198, 171, 171, 79, 79, 79, 79, 171, 170, 171, 79, 79, 170, 171, 170, 170, 170, 277, 277, 277, 277, 277, 277, 277, 200, 152, 152, 152, 152, 152, 152, 152, 152, 20, 20, 20, 267, 152, 20, 267, 20, 267, 275, 20, 267, 20, 267, 275, 275, 232, 275, 232, 232, 232, 232, 232, 232, 232, 79, 232, 232, 232, 232, 232, 79, 232, 232, 232, 232, 232, 232, 232, 79, 232, 232, 232, 144, 232, 144, 144, 144, 79, 144, 79, 144, 79, 144, 232, 79, 144, 144, 79, 79, 79, 232, 232, 144, 232, 144, 79, 144, 79, 79, 144, 232, 144, 144, 79, 144, 79, 144, 79, 79, 144, 232, 144, 144, 79, 144, 144, 144, 79, 144, 144, 79, 144, 144, 144, 144, 144, 144, 144, 144, 144, 232, 144, 232, 79, 79, 144, 144, 232, 232, 79, 144, 249, 79, 144, 62, 79, 144, 62, 62, 62, 62, 62, 62, 62, 249, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 171, 62, 62, 259, 171, 259, 62, 62, 171, 259, 171, 62, 62, 62, 171, 62, 62, 259, 259, 138, 259, 138, 138, 138, 138, 138, 138, 138, 138, 138, 138, 138, 138, 138, 138, 138, 335, 138, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 335, 321, 335, 321, 321, 321, 321, 321, 321, 321, 213, 213, 321, 213, 321, 321, 213, 321, 321, 213, 321, 321, 321, 213, 325, 325, 321, 325, 321, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325, 325]

# %% [markdown]
# ## Now train and predict

# %%
model.learn(total_timesteps=200000, log_interval=4)
model.save("simpleTel-DQNv1-model")
# Out:
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 378         |
# |    ep_rew_mean          | 9.06        |
# | time/                   |             |
# |    fps                  | 1080        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.074966915 |
# |    clip_fraction        | 0.634       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.118      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.103      |
# |    value_loss           | 0.02        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 8.92       |
# | time/                   |            |
# |    fps                  | 1047       |
# |    iterations           | 8          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.07637395 |
# |    clip_fraction        | 0.602      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.68      |
# |    explained_variance   | 0.617      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.115     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0935    |
# |    value_loss           | 0.0213     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 9.09       |
# | time/                   |            |
# |    fps                  | 1040       |
# |    iterations           | 12         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.07899356 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.46      |
# |    explained_variance   | 0.32       |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.113     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0878    |
# |    value_loss           | 0.0283     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 378         |
# |    ep_rew_mean          | 9.2         |
# | time/                   |             |
# |    fps                  | 1035        |
# |    iterations           | 16          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.090999275 |
# |    clip_fraction        | 0.624       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.141      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0976     |
# |    value_loss           | 0.0148      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 378       |
# |    ep_rew_mean          | 9.5       |
# | time/                   |           |
# |    fps                  | 1032      |
# |    iterations           | 20        |
# |    time_elapsed         | 39        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0955553 |
# |    clip_fraction        | 0.601     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.21     |
# |    explained_variance   | 0.784     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.121    |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -0.0899   |
# |    value_loss           | 0.0222    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 378         |
# |    ep_rew_mean          | 10          |
# | time/                   |             |
# |    fps                  | 1033        |
# |    iterations           | 24          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.102095276 |
# |    clip_fraction        | 0.614       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.17       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.115      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0817     |
# |    value_loss           | 0.0211      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 10.6       |
# | time/                   |            |
# |    fps                  | 1031       |
# |    iterations           | 28         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.12707585 |
# |    clip_fraction        | 0.655      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.95      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0896    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0913    |
# |    value_loss           | 0.0259     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 10.8       |
# | time/                   |            |
# |    fps                  | 1031       |
# |    iterations           | 32         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.12072593 |
# |    clip_fraction        | 0.636      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.07      |
# |    explained_variance   | 0.667      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0992    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0837    |
# |    value_loss           | 0.0259     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 11.2       |
# | time/                   |            |
# |    fps                  | 1030       |
# |    iterations           | 36         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.14818248 |
# |    clip_fraction        | 0.669      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.78      |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.122     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0926    |
# |    value_loss           | 0.0282     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 11.5       |
# | time/                   |            |
# |    fps                  | 1026       |
# |    iterations           | 40         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.19772527 |
# |    clip_fraction        | 0.631      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.64      |
# |    explained_variance   | 0.831      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.141     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0864    |
# |    value_loss           | 0.0296     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 12.1       |
# | time/                   |            |
# |    fps                  | 1025       |
# |    iterations           | 44         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.18362042 |
# |    clip_fraction        | 0.633      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.36      |
# |    explained_variance   | 0.874      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.142     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0812    |
# |    value_loss           | 0.0291     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 378         |
# |    ep_rew_mean          | 13          |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 48          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.118494675 |
# |    clip_fraction        | 0.622       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0625     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0744     |
# |    value_loss           | 0.025       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 14.2       |
# | time/                   |            |
# |    fps                  | 1022       |
# |    iterations           | 52         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.13991767 |
# |    clip_fraction        | 0.621      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.73      |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.117     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0833    |
# |    value_loss           | 0.0348     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 15.8       |
# | time/                   |            |
# |    fps                  | 1022       |
# |    iterations           | 56         |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.11578649 |
# |    clip_fraction        | 0.581      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.85      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.102     |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0627    |
# |    value_loss           | 0.0385     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 378       |
# |    ep_rew_mean          | 17.3      |
# | time/                   |           |
# |    fps                  | 1022      |
# |    iterations           | 60        |
# |    time_elapsed         | 120       |
# |    total_timesteps      | 122880    |
# | train/                  |           |
# |    approx_kl            | 0.1425084 |
# |    clip_fraction        | 0.591     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.38     |
# |    explained_variance   | 0.947     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.095    |
# |    n_updates            | 590       |
# |    policy_gradient_loss | -0.0712   |
# |    value_loss           | 0.0354    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 18.9       |
# | time/                   |            |
# |    fps                  | 1023       |
# |    iterations           | 64         |
# |    time_elapsed         | 128        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.11186209 |
# |    clip_fraction        | 0.512      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0953    |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.0592    |
# |    value_loss           | 0.0467     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 20.7       |
# | time/                   |            |
# |    fps                  | 1022       |
# |    iterations           | 68         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.09548093 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.03      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0637    |
# |    n_updates            | 670        |
# |    policy_gradient_loss | -0.0531    |
# |    value_loss           | 0.0382     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 23         |
# | time/                   |            |
# |    fps                  | 1023       |
# |    iterations           | 72         |
# |    time_elapsed         | 144        |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.13395452 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.42      |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.071     |
# |    n_updates            | 710        |
# |    policy_gradient_loss | -0.0523    |
# |    value_loss           | 0.0314     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 24.7       |
# | time/                   |            |
# |    fps                  | 1023       |
# |    iterations           | 76         |
# |    time_elapsed         | 152        |
# |    total_timesteps      | 155648     |
# | train/                  |            |
# |    approx_kl            | 0.09857601 |
# |    clip_fraction        | 0.479      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.56      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0651    |
# |    n_updates            | 750        |
# |    policy_gradient_loss | -0.0381    |
# |    value_loss           | 0.027      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 378         |
# |    ep_rew_mean          | 26.4        |
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 80          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.090907976 |
# |    clip_fraction        | 0.473       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0378     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 0.0327      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 28.2       |
# | time/                   |            |
# |    fps                  | 1024       |
# |    iterations           | 84         |
# |    time_elapsed         | 167        |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.20346871 |
# |    clip_fraction        | 0.46       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2         |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0636    |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.0344    |
# |    value_loss           | 0.0336     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 28.5       |
# | time/                   |            |
# |    fps                  | 1024       |
# |    iterations           | 88         |
# |    time_elapsed         | 175        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.26646388 |
# |    clip_fraction        | 0.557      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0662    |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0397    |
# |    value_loss           | 0.0513     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 26.5       |
# | time/                   |            |
# |    fps                  | 1024       |
# |    iterations           | 92         |
# |    time_elapsed         | 183        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.16711436 |
# |    clip_fraction        | 0.574      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.92      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.088     |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0305    |
# |    value_loss           | 0.0307     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 378        |
# |    ep_rew_mean          | 24.2       |
# | time/                   |            |
# |    fps                  | 1024       |
# |    iterations           | 96         |
# |    time_elapsed         | 191        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.42548734 |
# |    clip_fraction        | 0.644      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.1       |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0688    |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.0402    |
# |    value_loss           | 0.055      |
# ----------------------------------------

# %%
observation_list = []
reward_list = []
terminated_list = []
truncated_list = []
info_list = []

obs, info = env.reset()
observation_list.append(obs)
info_list.append(info)
for i in range(len(target_sequence)):
    action, _states = model.predict(obs, deterministic=False)
    obs, reward, terminated, truncated, info = env.step(action.tolist())
    observation_list.append(obs)
    reward_list.append(reward)
    terminated_list.append(terminated)
    truncated_list.append(truncated)
    info_list.append(info)
    if terminated or truncated:
        print(i)
        break
# Out:
# 377

# %%
proposed_survey = [observation_list[i]['field_id'] for i in range(len(observation_list))]
print(proposed_survey)
# Out:
# [29, 49, 1, 49, 33, 66, 49, 35, 34, 49, 33, 66, 35, 34, 353, 66, 34, 35, 34, 106, 353, 341, 341, 34, 35, 35, 183, 34, 341, 341, 183, 105, 183, 131, 183, 105, 1, 66, 68, 183, 266, 35, 353, 266, 353, 105, 96, 131, 353, 183, 353, 34, 353, 353, 105, 183, 34, 183, 183, 105, 49, 353, 66, 158, 253, 105, 353, 148, 105, 353, 253, 131, 341, 34, 353, 231, 146, 105, 131, 131, 100, 105, 359, 183, 296, 341, 34, 105, 322, 105, 35, 35, 131, 101, 131, 296, 35, 131, 231, 131, 131, 68, 131, 131, 253, 131, 105, 253, 131, 146, 360, 253, 131, 145, 14, 253, 131, 253, 253, 253, 253, 35, 17, 14, 17, 253, 253, 105, 35, 17, 253, 253, 131, 349, 83, 35, 253, 349, 253, 349, 35, 54, 253, 369, 143, 349, 349, 253, 349, 92, 162, 349, 349, 35, 211, 349, 253, 349, 211, 253, 349, 349, 211, 349, 105, 162, 131, 253, 349, 349, 106, 131, 349, 349, 349, 146, 349, 349, 105, 162, 349, 162, 100, 349, 369, 349, 162, 349, 106, 14, 253, 106, 349, 162, 349, 349, 17, 211, 106, 106, 100, 106, 349, 349, 106, 135, 162, 211, 106, 349, 349, 349, 253, 135, 92, 349, 105, 296, 106, 349, 27, 35, 100, 349, 106, 349, 349, 35, 162, 211, 349, 35, 135, 106, 349, 211, 211, 349, 315, 349, 17, 349, 349, 162, 211, 211, 17, 349, 349, 349, 349, 349, 211, 349, 349, 349, 35, 369, 349, 17, 349, 129, 100, 349, 211, 35, 105, 253, 349, 223, 135, 349, 211, 349, 106, 220, 349, 369, 106, 349, 349, 131, 106, 162, 349, 349, 106, 349, 349, 211, 349, 349, 349, 253, 27, 17, 106, 17, 349, 349, 349, 106, 349, 349, 211, 349, 349, 106, 349, 349, 27, 106, 349, 349, 106, 349, 349, 105, 349, 211, 35, 211, 349, 349, 106, 349, 349, 211, 360, 349, 106, 35, 82, 135, 349, 349, 17, 349, 17, 349, 349, 349, 349, 253, 17, 162, 27, 68, 162, 349, 17, 349, 349, 100, 162, 17, 349, 349, 68, 162, 106, 106, 349, 211, 106, 349, 135, 349, 349, 349, 349, 27, 106, 135, 349, 349, 349, 162, 349]

# %%
print(target_sequence)
# Out:
# [29, 31, 34, 37, 40, 28, 32, 35, 38, 41, 47, 51, 54, 57, 60, 46, 52, 55, 58, 60, 23, 24, 25, 26, 27, 30, 33, 36, 39, 42, 48, 53, 56, 59, 61, 22, 49, 66, 68, 73, 74, 21, 50, 65, 67, 72, 75, 69, 62, 78, 81, 90, 93, 71, 63, 76, 79, 89, 91, 70, 64, 77, 80, 88, 92, 115, 113, 114, 112, 119, 117, 116, 118, 127, 126, 124, 125, 123, 121, 122, 120, 156, 154, 155, 153, 152, 150, 149, 151, 166, 163, 164, 165, 141, 138, 140, 139, 131, 133, 134, 132, 130, 128, 129, 137, 135, 135, 136, 145, 143, 144, 142, 148, 147, 147, 146, 158, 161, 174, 176, 189, 193, 159, 162, 175, 178, 187, 194, 157, 160, 173, 177, 188, 192, 213, 197, 185, 167, 183, 214, 198, 186, 168, 184, 208, 226, 227, 220, 212, 207, 225, 228, 219, 211, 196, 180, 182, 191, 209, 195, 179, 181, 190, 210, 172, 169, 171, 170, 205, 199, 222, 216, 233, 229, 203, 200, 221, 215, 234, 230, 204, 201, 223, 218, 236, 231, 206, 202, 224, 217, 235, 232, 237, 241, 246, 251, 253, 278, 239, 242, 245, 249, 254, 277, 240, 244, 248, 252, 256, 279, 238, 243, 247, 250, 255, 276, 266, 267, 271, 274, 280, 283, 265, 268, 270, 273, 282, 285, 264, 269, 272, 275, 281, 284, 351, 348, 355, 0, 353, 349, 354, 1, 352, 350, 356, 2, 298, 297, 299, 296, 301, 302, 303, 300, 9, 6, 3, 12, 15, 18, 85, 106, 109, 104, 100, 83, 97, 94, 43, 10, 7, 4, 13, 16, 19, 86, 107, 110, 103, 101, 82, 98, 95, 45, 11, 8, 5, 14, 17, 20, 87, 108, 111, 105, 102, 84, 99, 96, 44, 263, 261, 261, 262, 261, 260, 295, 294, 292, 294, 293, 293, 305, 307, 304, 306, 306, 304, 288, 259, 291, 309, 286, 257, 289, 308, 287, 258, 290, 310, 320, 321, 347, 313, 335, 344, 319, 345, 311, 334, 342, 317, 318, 346, 312, 333, 343, 325, 315, 327, 330, 337, 331, 339, 341, 322, 316, 326, 329, 336, 332, 338, 340, 323, 314, 324, 328, 369, 368, 367, 366, 364, 362, 365, 363, 361, 360, 358, 357, 359]

# %%
fig, axs = plt.subplots(2)
axs[0].plot(np.array(target_sequence), marker='o', label='target', color='grey', linestyle='dashed', lw=3)
axs[0].plot(np.array(proposed_survey), marker='o', label='pred')
axs[0].legend()

axs[1].plot(np.array(target_sequence) - np.array(proposed_survey), marker='o')
axs[1].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
evaluate_policy(model, env)
# Out:
# (13.000000178813934, 0.0)

# %% [markdown]
# # Use monitor

# %%
env = Monitor(env)

# %%
model = DQN(
    "MultiInputPolicy",
    env,
    verbose=1,
    learning_rate=.0001,
    target_update_interval=int(len(target_sequence)*3),
)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000, log_interval=4)
model.save("simpleTel-DQNv1")
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 10723    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 116      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.027    |
# |    n_updates        | 3        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.67     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4563     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 232      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 32       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.18     |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3651     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 348      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0731   |
# |    n_updates        | 61       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.46     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3327     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 464      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.128    |
# |    n_updates        | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.55     |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3114     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 580      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0739   |
# |    n_updates        | 119      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.48     |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2982     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 696      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.188    |
# |    n_updates        | 148      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.4      |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2899     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 812      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0706   |
# |    n_updates        | 177      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.45     |
# |    exploration_rate | 0.559    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2848     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 928      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0695   |
# |    n_updates        | 206      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.46     |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2794     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1044     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0739   |
# |    n_updates        | 235      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2749     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1160     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.155    |
# |    n_updates        | 264      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.394    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2720     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1276     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.153    |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.53     |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2738     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1392     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.195    |
# |    n_updates        | 322      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.53     |
# |    exploration_rate | 0.284    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2732     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1508     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.53     |
# |    exploration_rate | 0.229    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2730     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1624     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.19     |
# |    n_updates        | 380      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.51     |
# |    exploration_rate | 0.174    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2723     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1740     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.406    |
# |    n_updates        | 409      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.47     |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2716     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1856     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.131    |
# |    n_updates        | 438      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.41     |
# |    exploration_rate | 0.0633   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2705     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1972     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.254    |
# |    n_updates        | 467      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2688     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2088     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.292    |
# |    n_updates        | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2670     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2204     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.42     |
# |    n_updates        | 525      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2656     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2320     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.215    |
# |    n_updates        | 554      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2644     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2436     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0761   |
# |    n_updates        | 583      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2633     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2552     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.932    |
# |    n_updates        | 612      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2622     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2668     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0811   |
# |    n_updates        | 641      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2612     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2784     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.374    |
# |    n_updates        | 670      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2601     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2900     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 699      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2591     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3016     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0574   |
# |    n_updates        | 728      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2583     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3132     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.439    |
# |    n_updates        | 757      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2573     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3248     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 786      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2565     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3364     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 815      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2559     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3480     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.6      |
# |    n_updates        | 844      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2554     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3596     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 873      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2547     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3712     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.736    |
# |    n_updates        | 902      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2542     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3828     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0829   |
# |    n_updates        | 931      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2538     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3944     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 960      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2533     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4060     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.323    |
# |    n_updates        | 989      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2529     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4176     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.238    |
# |    n_updates        | 1018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2527     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4292     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.1      |
# |    n_updates        | 1047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2525     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4408     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0937   |
# |    n_updates        | 1076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2521     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4524     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.376    |
# |    n_updates        | 1105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2519     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4640     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 1134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2519     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4756     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 1163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2519     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4872     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26     |
# |    n_updates        | 1192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2514     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4988     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82     |
# |    n_updates        | 1221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2512     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5104     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 1250     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2510     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5220     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.295    |
# |    n_updates        | 1279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 2.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2509     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5336     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.913    |
# |    n_updates        | 1308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 2.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2505     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5452     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09     |
# |    n_updates        | 1337     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 2.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2503     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5568     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.23     |
# |    n_updates        | 1366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 2.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2502     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5684     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.08     |
# |    n_updates        | 1395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 2.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2502     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.745    |
# |    n_updates        | 1424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 2.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2501     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5916     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.5      |
# |    n_updates        | 1453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 2.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2500     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6032     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8        |
# |    n_updates        | 1482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2497     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6148     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.42     |
# |    n_updates        | 1511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2495     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6264     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.45     |
# |    n_updates        | 1540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2495     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6380     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.854    |
# |    n_updates        | 1569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2495     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6496     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.91     |
# |    n_updates        | 1598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2494     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6612     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.59     |
# |    n_updates        | 1627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2495     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6728     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.93     |
# |    n_updates        | 1656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2495     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6844     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.24     |
# |    n_updates        | 1685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2496     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6960     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.1     |
# |    n_updates        | 1714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2497     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7076     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.8      |
# |    n_updates        | 1743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2498     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7192     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14       |
# |    n_updates        | 1772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 2497     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7308     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.27     |
# |    n_updates        | 1801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2494     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7424     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 17.2     |
# |    n_updates        | 1830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2491     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7540     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 1859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2489     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7656     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.99     |
# |    n_updates        | 1888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2484     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7772     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.45     |
# |    n_updates        | 1917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2481     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7888     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.34     |
# |    n_updates        | 1946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2482     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8004     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.21     |
# |    n_updates        | 1975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2482     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8120     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.06     |
# |    n_updates        | 2004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2483     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8236     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.04     |
# |    n_updates        | 2033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2484     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8352     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.75     |
# |    n_updates        | 2062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2483     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8468     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.5     |
# |    n_updates        | 2091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.41     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2481     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8584     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.4     |
# |    n_updates        | 2120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.41     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2481     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8700     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 19.7     |
# |    n_updates        | 2149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2480     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8816     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.46     |
# |    n_updates        | 2178     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2478     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8932     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 24.7     |
# |    n_updates        | 2207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2479     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9048     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.95     |
# |    n_updates        | 2236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2479     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9164     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.6     |
# |    n_updates        | 2265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2480     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9280     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 20.1     |
# |    n_updates        | 2294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2480     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9396     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 19.5     |
# |    n_updates        | 2323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2479     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9512     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.9      |
# |    n_updates        | 2352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2480     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9628     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 29.8     |
# |    n_updates        | 2381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2480     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9744     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.8     |
# |    n_updates        | 2410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2480     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9860     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.22     |
# |    n_updates        | 2439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2478     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9976     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.13     |
# |    n_updates        | 2468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2476     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10092    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 42.3     |
# |    n_updates        | 2497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2476     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 58.4     |
# |    n_updates        | 2526     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2476     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10324    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.7     |
# |    n_updates        | 2555     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2474     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.6     |
# |    n_updates        | 2584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2474     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 38.7     |
# |    n_updates        | 2613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.5      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# ...
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16472    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 416      |
# |    n_updates        | 4092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 2459     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16588    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 320      |
# |    n_updates        | 4121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 2458     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16704    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 362      |
# |    n_updates        | 4150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 2457     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16820    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 239      |
# |    n_updates        | 4179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 2456     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16936    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 408      |
# |    n_updates        | 4208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 2456     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 17052    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 331      |
# |    n_updates        | 4237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 2455     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 17168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 375      |
# |    n_updates        | 4266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 2455     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17284    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 196      |
# |    n_updates        | 4295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 2455     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 232      |
# |    n_updates        | 4324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 2455     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 443      |
# |    n_updates        | 4353     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 2455     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17632    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 481      |
# |    n_updates        | 4382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 2454     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17748    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 467      |
# |    n_updates        | 4411     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 2454     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17864    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 539      |
# |    n_updates        | 4440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 2454     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 318      |
# |    n_updates        | 4469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 2453     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18096    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 534      |
# |    n_updates        | 4498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 2453     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18212    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 599      |
# |    n_updates        | 4527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 2452     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18328    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 206      |
# |    n_updates        | 4556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 2452     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18444    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 812      |
# |    n_updates        | 4585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 2452     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 342      |
# |    n_updates        | 4614     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 2452     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18676    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 516      |
# |    n_updates        | 4643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 2452     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 351      |
# |    n_updates        | 4672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 2451     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18908    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 576      |
# |    n_updates        | 4701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 2451     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19024    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 376      |
# |    n_updates        | 4730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 2451     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19140    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 402      |
# |    n_updates        | 4759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 2451     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19256    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 613      |
# |    n_updates        | 4788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 2450     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19372    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 528      |
# |    n_updates        | 4817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 2450     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 558      |
# |    n_updates        | 4846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 2450     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19604    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 314      |
# |    n_updates        | 4875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 2450     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19720    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 284      |
# |    n_updates        | 4904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 2450     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19836    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 594      |
# |    n_updates        | 4933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 3.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 2450     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19952    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 688      |
# |    n_updates        | 4962     |
# ----------------------------------

# %%
observation_list = []
reward_list = []
terminated_list = []
truncated_list = []
info_list = []

obs, info = env.reset()
observation_list.append(obs)
info_list.append(info)
for i in range(len(target_sequence)):
    action, _states = model.predict(obs, deterministic=False)
    obs, reward, terminated, truncated, info = env.step(action.tolist())
    observation_list.append(obs)
    reward_list.append(reward)
    terminated_list.append(terminated)
    truncated_list.append(truncated)
    info_list.append(info)
    if terminated or truncated:
        print(i)
        break
# Out:
# 28

# %%
proposed_survey = [observation_list[i]['field_id'] for i in range(len(observation_list))]
print(proposed_survey)
# Out:
# [1, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]

# %%
print(target_sequence)
# Out:
# [1, 7, 5, 5, 0, 8, 1, 2, 4, 5, 6, 8, 4, 6, 3, 4, 7, 9, 2, 6, 2, 3, 7, 1, 3, 8, 0, 0, 9, 9]

# %%
plt.plot(np.array(proposed_survey) - np.array(target_sequence), marker='o')
