# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, TensorDataset
import gymnasium as gym

from astropy.io import fits
from datetime import datetime
import json
# import fitsio
import pandas as pd
import time
import pickle
import re


# %reload_ext autoreload
# %autoreload 2

# %%
import survey_ops
from survey_ops.utils import units, geometry, interpolate
from survey_ops.src.offline_dataset import OfflineDECamDataset
from survey_ops.src.agents import Agent
from survey_ops.src.algorithms import DDQN, BehaviorCloning
from survey_ops.utils.pytorch_utils import seed_everything

# %%
SEED = 10
seed_everything(SEED)
torch.set_default_dtype(torch.float32)
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "cpu"   
)

# %% [markdown]
# # Load and cut data from fits file, save as .json

# %%
data_json_fn = '../data/data_w_dith.json'
data_fits_fn = '../data/decam-exposures-20251211_w_dith.fits'

try:
    # --- Load json df ---- #
    df = pd.read_json(data_json_fn)
    print('Loaded data from json')
except:
    # --- Load fits ---- #
    print(data_json_fn, 'DNE. Loading and processing data from fits.')
    d = fitsio.read(data_fits_fn)
    sel = (d['propid'] == '2012B-0001') & (d['exptime'] > 40) & (d['exptime'] < 100) & (~np.isnan(d['teff']))
    selected_d = d[sel]
    column_names = selected_d.dtype.names
    df = pd.DataFrame(selected_d, columns=column_names)
    
    # mask = np.array([False if 'None' in dt else True for dt in subs_data['datetime']])
    # subs_data = {key: subs_data[key][mask] for key in subs_data.keys()}
    
    df.to_json(data_json_fn, indent=2)
    df = pd.read_json(data_json_fn)
# Out:
# Loaded data from json

# %% [markdown]
# # Instantiate the offline dataset choosing binning method (healpix vs uniform_grid)

# %%
binning_method='healpix'
nside=8
bin_space='radec'
# specific_years=[2014]
# specific_months=[12],
# specific_days=[15, 16, 17],
include_default_features=True
include_bin_features=False
do_z_score_norm=True
do_cyclical_norm=True

# %%
dataset = OfflineDECamDataset(
    df, 
    binning_method=binning_method,
    nside=nside,
    bin_space=bin_space,
    # specific_years=specific_years,
    # specific_months=[12],
    # specific_days=[15, 16, 17],
    include_default_features=include_default_features,
    include_bin_features=include_bin_features,
    do_z_score_norm=do_z_score_norm,
    do_cyclical_norm=do_cyclical_norm,
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dataset = OfflineDECamDataset(
#       2     df,
#       3     binning_method=binning_method,
#       4     nside=nside,
#       5     bin_space=bin_space,
#       6     # specific_years=specific_years,
#       7     # specific_months=[12],
#       8     # specific_days=[15, 16, 17],
#       9     include_default_features=include_default_features,
#      10     include_bin_features=include_bin_features,
#      11     do_z_score_norm=do_z_score_norm,
#      12     do_cyclical_norm=do_cyclical_norm,
#      13 )
#
# File ~/Projects/survey-ops/survey_ops/src/offline_dataset.py:127, in OfflineDECamDataset.__init__(self, df, specific_years, specific_months, specific_days, specific_filters, binning_method, bin_space, nside, num_bins_1d, additional_pointing_features, additional_bin_features, include_default_features, include_bin_features, do_z_score_norm, do_cyclical_norm)
#     124 self.n_obs_per_night = groups_by_night.size() # nights have different numbers of observations
#     126 # Construct Transitions
# --> 127 states, next_states = self._construct_states(df=df, include_bin_features=include_bin_features, bin_feature_names=bin_feature_names)
#     128 actions = self._construct_actions(df, num_bins_1d=num_bins_1d, binning_method=binning_method, bin_space=bin_space)
#     129 rewards = self._construct_rewards(df)
#
# File ~/Projects/survey-ops/survey_ops/src/offline_dataset.py:386, in OfflineDECamDataset._construct_states(self, df, include_bin_features, bin_feature_names)
#     385 def _construct_states(self, df, include_bin_features, bin_feature_names):
# --> 386     pointing_features, next_pointing_features = self._construct_pointing_features(df=df)
#     387     if include_bin_features:
#     388         bin_features, bin_next_features = self._get_bin_features(df=df, bin_feature_names=bin_feature_names)
#
# File ~/Projects/survey-ops/survey_ops/src/offline_dataset.py:332, in OfflineDECamDataset._construct_pointing_features(self, df)
#     330 # "States" require inserting rows of 0's before first observation of each night, and deleting last observation
#     331 night_end_indices = df.groupby('night').tail(1).index - df.head(1).index
# --> 332 pointing_features[night_end_indices[:-1]] = 0 # Replace last observation of each night with 0's, except last observation of entire self
#     333 pointing_features = pointing_features[:-1, :] # remove last observation row
#     334 zero_row = np.zeros_like(pointing_features[0]) # insert row of 0s in front of first observation
#
# IndexError: index 88563 is out of bounds for axis 0 with size 88541
